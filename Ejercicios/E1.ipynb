# %% [markdown]
# # Ejercicio: Funciones Lineales

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## f(x) = 2x+3  Arreglo aleatrio de 10 números enteros entre 0 y 100

# %%
np.random.seed()

x1 = np.random.randint(0, 100, 10)

print(x1)

y1 = (2 * x1) + 3

plt.plot(x1, y1)
plt.title("f(x) = 2x+3")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [21 69 59 87 60 96 52 35 96 82]

# %%
x2 = np.random.uniform(-10, 10, 20)

print(x2)

y2 = (0.5 * x2) - 1

plt.plot(x2, y2)
plt.title("f(x) = 0.5x-1")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [-2.4689538   0.54936336  4.78047691  2.99178872 -2.71737054  2.11325766
#  -6.07367779 -7.10468543 -0.16494289  0.82322507 -0.07096604 -7.91389766
#  -0.22308042  8.16584062  4.80712942 -5.20717661  5.70021556  1.93853876
#   6.10277419  6.71756096]

# %%
x3 = np.random.randint(-50, -10, 15)

print(x3)

y3 = (-3 * x3) + 2

plt.plot(x3, y3)
plt.title("f(x) = -3x+2")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [-44 -23 -32 -48 -50 -17 -30 -11 -36 -39 -22 -26 -15 -12 -19]

# %%
x4 = np.random.uniform(0, 5, 12)

print(x4)

y4 = 4 * x4

plt.plot(x4, y4)
plt.title("f(x) = 4x")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [3.1886893  1.70842707 0.30973475 0.68485237 3.16610134 0.15261463
#  2.86278954 2.12675878 1.52151924 0.03322164 1.74649854 3.89790342]

# %%
x5 = np.random.randint(-100, 100, 8)

print(x5)

y5 = -2 * x5

plt.plot(x5, y5)
plt.title("f(x) = -2x")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [-97  45  87  40  42  55  66 -78]

# %%
x6 = np.random.uniform(-20, 20, 25)

print(x6)

y6 = x6 + 1

plt.plot(x6, y6)
plt.title("f(x) = x+1")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [ 17.44843294  -1.47427406   7.6675703    9.36160709  -1.6242544
#   -6.49203224  16.62539058   0.99890283  19.54038441  10.26783399
#   -9.29668041  -2.57802169  13.91672115   7.20770496 -10.06506607
#   -9.30920182 -19.39171058  -7.7245805    9.27251342 -12.08044915
#  -13.01155388  12.39546688 -16.1098027   -6.66005518  16.99642957]

# %%
x7 = np.random.randint(-200, -50, 18)

print(x7)

y7 = (-0.5 * x7) 

plt.plot(x7, y7)
plt.title("f(x) = -0.5x")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [-190 -199  -63  -68  -72  -75 -148 -167 -191 -183 -166 -148 -151 -167
#   -80  -56 -171 -132]

# %%
x8 = np.random.uniform(-3, 3, 30)

print(x8)

y8 = 3 + (x8-x8)

plt.plot(x8, y8)
plt.title("f(x) = 3")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# [ 0.169518    2.06644765  0.90159404  0.12636792 -0.97370025  2.63806116
#  -2.01692842 -0.37289223 -1.7706677   1.96528991  1.53539538  2.61644254
#  -1.58258854  1.52597315  1.88607542  2.28060395 -2.90899196  1.59183916
#   0.65757034 -0.90823607 -1.07247036 -1.30461858  2.92252482  2.03663857
#   1.0607959   1.99885137  2.18475077 -0.30847771 -2.8046194   2.91433951]

# %%
x9 = np.random.uniform(50, 100, 15)

print(x9)

y9 =-4+(x9-x9)

plt.plot(x9, y9)
plt.title("f(x) = -4")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# [69.81638481 58.8512614  66.54175562 83.18090904 61.75960357 99.86078511
#  53.0648854  93.40654868 82.30105426 96.80604356 60.17773186 58.73659431
#  66.30946644 90.40788711 54.25528744]

# %%
x10 = np.random.randint(2, 8, 20)

print(x10)

y10 = (2 * x10) -5

plt.plot(x10, y10)
plt.title("f(x) = 2x - 5")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# [2 3 7 7 2 6 7 5 3 3 5 3 6 7 7 7 5 6 4 2]
